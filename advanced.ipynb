# %%
import pandas as pd

# %%
coffee=pd.read_csv("./warmup-data/coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee["price"]=15

# %%
coffee["revenue"]=coffee["Units Sold"]*coffee["price"]

# %%
coffee["yesturday"]=coffee["revenue"].shift(1)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesturday
# 0      Monday    Espresso          25     15      375        NaN
# 1      Monday       Latte          15     15      225      375.0
# 2     Tuesday    Espresso          30     15      450      225.0
# 3     Tuesday       Latte          20     15      300      450.0
# 4   Wednesday    Espresso          35     15      525      300.0
# 5   Wednesday       Latte          25     15      375      525.0
# 6    Thursday    Espresso          40     15      600      375.0
# 7    Thursday       Latte          30     15      450      600.0
# 8      Friday    Espresso          45     15      675      450.0
# 9      Friday       Latte          35     15      525      675.0
# 10   Saturday    Espresso          45     15      675      525.0
# 11   Saturday       Latte          35     15      525      675.0
# 12     Sunday    Espresso          45     15      675      525.0
# ...

# %%
coffee["change"]=coffee["revenue"]/coffee["yesturday"]*100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesturday      change
# 0      Monday    Espresso          25     15      375        NaN         NaN
# 1      Monday       Latte          15     15      225      375.0   60.000000
# 2     Tuesday    Espresso          30     15      450      225.0  200.000000
# 3     Tuesday       Latte          20     15      300      450.0   66.666667
# 4   Wednesday    Espresso          35     15      525      300.0  175.000000
# 5   Wednesday       Latte          25     15      375      525.0   71.428571
# 6    Thursday    Espresso          40     15      600      375.0  160.000000
# 7    Thursday       Latte          30     15      450      600.0   75.000000
# 8      Friday    Espresso          45     15      675      450.0  150.000000
# 9      Friday       Latte          35     15      525      675.0   77.777778
# 10   Saturday    Espresso          45     15      675      525.0  128.571429
# ...

# %%
bios=pd.read_csv("./data/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios["height_rank"]=bios["height_cm"].rank()

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios["height_rank"].sort_values(ascending=False)
# Out:
# 89070     106651.0
# 5781      106649.5
# 6978      106649.5
# 89075     106647.0
# 120266    106647.0
#             ...
# 145490         NaN
# 145491         NaN
# 145492         NaN
# 145493         NaN
# 145499         NaN
# Name: height_rank, Length: 145500, dtype: float64

# %%
bios["height_rank"]=bios["height_cm"].rank(ascending=False)

# %%
bios.sort_values(["height_rank"]).sample(10)
# Out:
#         athlete_id              name   born_date              born_city  \
# 37577        37875    Otmar Kaufhold  1952-06-28                 Bremen
# 37019        37314       Jack Godwin  1904-03-18              Beckenham
# 62685        63151       Gyula Nyári  1965-03-31         Székesfehérvár
# 46539        46887     Ernest Martin  1878-01-01                    NaN
# 47029        47379  George Robertson  1900-10-14               Shanghai
# 11184        11243       Jack Hickey  1887-01-04                 Sydney
# 79839        80489  Alexandra Fouace  1979-07-07  Cherbourg-en-Cotentin
# 18606        18733      Bob Cattrall  1957-10-07              Braintree
# 95135        95904   Aleksandr Nosov  1942-10-22                   Perm
# 109543      110738     Zhang Zhongqi  1982-11-02                Qiqihar
#
#             born_region born_country                         NOC  height_cm  \
# 37577            Bremen          GER                West Germany      191.0
# ...

# %%
coffee.select_dtypes('float').cumsum()
# Out:
#     yesturday       change
# 0         NaN          NaN
# 1       375.0    60.000000
# 2       600.0   260.000000
# 3      1050.0   326.666667
# 4      1350.0   501.666667
# 5      1875.0   573.095238
# 6      2250.0   733.095238
# 7      2850.0   808.095238
# 8      3300.0   958.095238
# 9      3975.0  1035.873016
# 10     4500.0  1164.444444
# 11     5175.0  1242.222222
# 12     5700.0  1370.793651
# 13     6375.0  1448.571429

# %%
coffee["cum_sum"]=coffee["revenue"].cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yesturday      change  \
# 0      Monday    Espresso          25     15      375        NaN         NaN
# 1      Monday       Latte          15     15      225      375.0   60.000000
# 2     Tuesday    Espresso          30     15      450      225.0  200.000000
# 3     Tuesday       Latte          20     15      300      450.0   66.666667
# 4   Wednesday    Espresso          35     15      525      300.0  175.000000
# 5   Wednesday       Latte          25     15      375      525.0   71.428571
# 6    Thursday    Espresso          40     15      600      375.0  160.000000
# 7    Thursday       Latte          30     15      450      600.0   75.000000
# 8      Friday    Espresso          45     15      675      450.0  150.000000
# 9      Friday       Latte          35     15      525      675.0   77.777778
# 10   Saturday    Espresso          45     15      675      525.0  128.571429
# ...

# %%
latte=coffee[coffee["Coffee Type"]=="Latte"].copy()

# %%
latte_3d=latte["Units Sold"].rolling(3).sum()

# %%
latte_3d
# Out:
# 1       NaN
# 3       NaN
# 5      60.0
# 7      75.0
# 9      90.0
# 11    100.0
# 13    105.0
# Name: Units Sold, dtype: float64
