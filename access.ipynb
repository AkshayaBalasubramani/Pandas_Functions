# %%
import pandas as pd

# %%
coffee=pd.read_csv("./warmup-data/coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee.sample(5)
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 11   Saturday       Latte          35
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
coffee.sample(5,random_state=1)
# Out:
#          Day Coffee Type  Units Sold
# 3    Tuesday       Latte          20
# 7   Thursday       Latte          30
# 6   Thursday    Espresso          40
# 2    Tuesday    Espresso          30
# 10  Saturday    Espresso          45

# %%
coffee.loc[0,"Coffee Type"]
# Out:
# 'Espresso'

# %%
coffee.loc[0:3,"Coffee Type"]
# Out:
# 0    Espresso
# 1       Latte
# 2    Espresso
# 3       Latte
# Name: Coffee Type, dtype: object

# %%
coffee.loc[0:3,["Coffee Type","Units Sold"]]
# Out:
#   Coffee Type  Units Sold
# 0    Espresso          25
# 1       Latte          15
# 2    Espresso          30
# 3       Latte          20

# %%
coffee.loc[:4,"Coffee Type"]
# Out:
# 0    Espresso
# 1       Latte
# 2    Espresso
# 3       Latte
# 4    Espresso
# Name: Coffee Type, dtype: object

# %%
df=coffee

# %%
df.index=df.Day

# %%
df
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
df.loc["Monday":"Wednesday",["Units Sold"]]
# Out:
#            Units Sold
# Day
# Monday             25
# Monday             15
# Tuesday            30
# Tuesday            20
# Wednesday          35
# Wednesday          25

# %%
df.iloc[0:3,[0,1]]
# Out:
#              Day Coffee Type
# Day
# Monday    Monday    Espresso
# Monday    Monday       Latte
# Tuesday  Tuesday    Espresso

# %%
coffee.iloc[0:4]
# Out:
#              Day Coffee Type  Units Sold
# Day
# Monday    Monday    Espresso          25
# Monday    Monday       Latte          15
# Tuesday  Tuesday    Espresso          30
# Tuesday  Tuesday       Latte          20

# %%
df.at["Monday","Units Sold"]
# Out:
# Day
# Monday    25
# Monday    15
# Name: Units Sold, dtype: int64

# %%
df.iat[0,2]
# Out:
# 25

# %%
df.sort_values("Units Sold")
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday       Latte          15
# Tuesday      Tuesday       Latte          20
# Monday        Monday    Espresso          25
# Wednesday  Wednesday       Latte          25
# Tuesday      Tuesday    Espresso          30
# Thursday    Thursday       Latte          30
# Wednesday  Wednesday    Espresso          35
# Friday        Friday       Latte          35
# Saturday    Saturday       Latte          35
# Sunday        Sunday       Latte          35
# Thursday    Thursday    Espresso          40
# Friday        Friday    Espresso          45
# Saturday    Saturday    Espresso          45
# Sunday        Sunday    Espresso          45

# %%
df.sort_values("Units Sold",ascending=False)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Friday        Friday    Espresso          45
# Saturday    Saturday    Espresso          45
# Sunday        Sunday    Espresso          45
# Thursday    Thursday    Espresso          40
# Wednesday  Wednesday    Espresso          35
# Friday        Friday       Latte          35
# Saturday    Saturday       Latte          35
# Sunday        Sunday       Latte          35
# Tuesday      Tuesday    Espresso          30
# Thursday    Thursday       Latte          30
# Monday        Monday    Espresso          25
# Wednesday  Wednesday       Latte          25
# Tuesday      Tuesday       Latte          20
# Monday        Monday       Latte          15

# %%
df.sort_values(["Coffee Type","Units Sold"],ascending=[0,1])
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday       Latte          15
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday       Latte          30
# Friday        Friday       Latte          35
# Saturday    Saturday       Latte          35
# Sunday        Sunday       Latte          35
# Monday        Monday    Espresso          25
# Tuesday      Tuesday    Espresso          30
# Wednesday  Wednesday    Espresso          35
# Thursday    Thursday    Espresso          40
# Friday        Friday    Espresso          45
# Saturday    Saturday    Espresso          45
# Sunday        Sunday    Espresso          45

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row)
# Out:
# Monday
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: Monday, dtype: object
# Monday
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: Monday, dtype: object
# Tuesday
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: Tuesday, dtype: object
# Tuesday
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: Tuesday, dtype: object
# Wednesday
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: Wednesday, dtype: object
# Wednesday
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: Wednesday, dtype: object
# Thursday
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: Thursday, dtype: object
# Thursday
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: Thursday, dtype: object
# Friday
# Day              Friday
# ...

# %%
for index,row in coffee.iterrows():
    print(index)
    print(row["Day"],"\n",row["Coffee Type"])
# Out:
# 0
# Monday
#  Espresso
# 1
# Monday
#  Latte
# 2
# Tuesday
#  Espresso
# 3
# Tuesday
#  Latte
# 4
# Wednesday
#  Espresso
# 5
# Wednesday
#  Latte
# 6
# Thursday
#  Espresso
# 7
# Thursday
#  Latte
# 8
# Friday
#  Espresso
# 9
# Friday
#  Latte
# 10
# Saturday
#  Espresso
# 11
# Saturday
#  Latte
# 12
# Sunday
#  Espresso
# 13
# Sunday
#  Latte
