# %%
import pandas as pd

# %%
bios=pd.read_csv("./data/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
nocs=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv")

# %%
nocs
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
bios_new=pd.merge(bios,nocs,left_on="born_country",right_on="NOC",how="inner")

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 110634      149222      Polina Luchnikova  2002-01-30            Serov
# 110635      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 110636      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 110637      149225         André Foussard  1899-05-19            Niort
# 110638      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 110634            Sverdlovsk          RUS        ROC      167.0       61.0
# 110635                Moskva          RUS        ROC      168.0       65.0
# 110636           Arkhangelsk          RUS        ROC      163.0       55.0
# 110637           Deux-Sèvres          FRA     France      166.0        NaN
# 110638       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date NOC_y     region notes
# 0       1960-10-02   FRA     France   NaN
# 1              NaN   FRA     France   NaN
# 2       1994-07-17   FRA     France   NaN
# 3       1978-03-20   FRA     France   NaN
# 4       1930-07-25   GBR         UK   NaN
# ...            ...   ...        ...   ...
# 110634         NaN   RUS     Russia   NaN
# 110635         NaN   RUS     Russia   NaN
# 110636         NaN   RUS     Russia   NaN
# 110637  1986-03-18   FRA     France   NaN
# 110638  2003-10-20   AUS  Australia   NaN
#
# [110639 rows x 13 columns]

# %%
bios_new.rename(columns={'region':"born_country_full"},inplace=True)

# %%
bios_new[bios_new['NOC_x']!=bios_new["born_country_full"]][["name","NOC_x",'born_country_full']]
# Out:
#                        name                NOC_x born_country_full
# 4              Albert Canet               France                UK
# 14               Guy Forget               France           Morocco
# 32          Helen Aitchison        Great Britain                UK
# 33        Geraldine Beamish        Great Britain                UK
# 34             Dora Boothby        Great Britain                UK
# ...                     ...                  ...               ...
# 110630         Shakeel John  Trinidad and Tobago          Trinidad
# 110632   Landysh Falyakhova                  ROC            Russia
# 110634    Polina Luchnikova                  ROC            Russia
# 110635  Valeriya Merkusheva                  ROC            Russia
# 110636      Yuliya Smirnova                  ROC            Russia
#
# [38349 rows x 3 columns]

# %%
usa=bios_new[bios_new["born_country"]=="USA"].copy()
gbr=bios_new[bios_new["born_country"]=="GBR"].copy()

# %%
usa
# Out:
#         athlete_id               name   born_date         born_city  \
# 48              55      Monique Javer  1967-07-22        Burlingame
# 697            964   Xóchitl Escobedo  1968-09-17       West Covina
# 698            965  Angélica Gavaldón  1973-10-03         El Centro
# 904           1238     Bert Schneider  1897-07-01         Cleveland
# 968           1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 110599      149168     Kristen Santos  1994-11-02         Fairfield
# 110600      149169   Corinne Stoddard  2001-08-15           Seattle
# 110606      149180      Anna Hoffmann  2000-03-28           Madison
# 110609      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 110620      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country          NOC_x  height_cm  weight_kg  \
# 48       California          USA  Great Britain      177.0       64.0
# 697      California          USA         Mexico      170.0       60.0
# 698      California          USA         Mexico      160.0       54.0
# 904            Ohio          USA         Canada        NaN        NaN
# 968      California          USA  United States      168.0       61.0
# ...             ...          ...            ...        ...        ...
# 110599  Connecticut          USA  United States        NaN        NaN
# 110600   Washington          USA  United States        NaN        NaN
# 110606    Wisconsin          USA  United States        NaN        NaN
# 110609   California          USA  United States        NaN        NaN
# 110620     Michigan          USA  United States      187.0       97.0
#
#          died_date NOC_y born_country_full notes
# 48             NaN   USA               USA   NaN
# 697            NaN   USA               USA   NaN
# 698            NaN   USA               USA   NaN
# 904     1986-02-20   USA               USA   NaN
# 968            NaN   USA               USA   NaN
# ...            ...   ...               ...   ...
# 110599         NaN   USA               USA   NaN
# 110600         NaN   USA               USA   NaN
# 110606         NaN   USA               USA   NaN
# 110609         NaN   USA               USA   NaN
# 110620         NaN   USA               USA   NaN
#
# [9641 rows x 13 columns]

# %%
gbr
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 4                5        Albert Canet  1878-04-17    Wandsworth     England
# 32              38     Helen Aitchison  1881-12-06    Sunderland     England
# 33              39   Geraldine Beamish  1883-06-23   Forest Gate     England
# 34              40        Dora Boothby  1881-08-02      Finchley     England
# 35              41      Julie Bradbury  1967-02-12        Oxford     England
# ...            ...                 ...         ...           ...         ...
# 110103      148512  Benjamin Alexander  1983-05-08        London     England
# 110104      148517       Ashley Watson  1993-10-28  Peterborough     England
# 110225      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 110482      149041          Axel Brown  1992-04-02     Harrogate     England
# 110545      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                NOC_x  height_cm  weight_kg   died_date  \
# 4               GBR               France        NaN        NaN  1930-07-25
# 32              GBR        Great Britain        NaN        NaN  1947-05-26
# 33              GBR        Great Britain        NaN        NaN  1972-05-10
# 34              GBR        Great Britain        NaN        NaN  1970-02-22
# 35              GBR        Great Britain      175.0       64.0         NaN
# ...             ...                  ...        ...        ...         ...
# 110103          GBR              Jamaica        NaN        NaN         NaN
# 110104          GBR              Jamaica        NaN        NaN         NaN
# 110225          GBR               Norway      184.0       86.0         NaN
# 110482          GBR  Trinidad and Tobago        NaN        NaN         NaN
# 110545          GBR        United States        NaN        NaN         NaN
#
#        NOC_y born_country_full notes
# 4        GBR                UK   NaN
# 32       GBR                UK   NaN
# 33       GBR                UK   NaN
# 34       GBR                UK   NaN
# 35       GBR                UK   NaN
# ...      ...               ...   ...
# 110103   GBR                UK   NaN
# 110104   GBR                UK   NaN
# 110225   GBR                UK   NaN
# 110482   GBR                UK   NaN
# 110545   GBR                UK   NaN
#
# [5792 rows x 13 columns]

# %%
new_df=pd.concat([usa,gbr])

# %%
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 48              55       Monique Javer  1967-07-22        Burlingame
# 697            964    Xóchitl Escobedo  1968-09-17       West Covina
# 698            965   Angélica Gavaldón  1973-10-03         El Centro
# 904           1238      Bert Schneider  1897-07-01         Cleveland
# 968           1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 110103      148512  Benjamin Alexander  1983-05-08            London
# 110104      148517       Ashley Watson  1993-10-28      Peterborough
# 110225      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 110482      149041          Axel Brown  1992-04-02         Harrogate
# 110545      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                NOC_x  height_cm  weight_kg  \
# 48      California          USA        Great Britain      177.0       64.0
# 697     California          USA               Mexico      170.0       60.0
# 698     California          USA               Mexico      160.0       54.0
# 904           Ohio          USA               Canada        NaN        NaN
# 968     California          USA        United States      168.0       61.0
# ...            ...          ...                  ...        ...        ...
# 110103     England          GBR              Jamaica        NaN        NaN
# 110104     England          GBR              Jamaica        NaN        NaN
# 110225     England          GBR               Norway      184.0       86.0
# 110482     England          GBR  Trinidad and Tobago        NaN        NaN
# 110545     England          GBR        United States        NaN        NaN
#
#          died_date NOC_y born_country_full notes
# 48             NaN   USA               USA   NaN
# 697            NaN   USA               USA   NaN
# 698            NaN   USA               USA   NaN
# 904     1986-02-20   USA               USA   NaN
# 968            NaN   USA               USA   NaN
# ...            ...   ...               ...   ...
# 110103         NaN   GBR                UK   NaN
# 110104         NaN   GBR                UK   NaN
# 110225         NaN   GBR                UK   NaN
# 110482         NaN   GBR                UK   NaN
# 110545         NaN   GBR                UK   NaN
#
# [15433 rows x 13 columns]
