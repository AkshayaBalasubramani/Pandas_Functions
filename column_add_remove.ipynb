# %%
import pandas as pd

# %%
coffee=pd.read_csv("./warmup-data/coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee_new=coffee.copy()

# %%
coffee_new["price"]=4.99

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  price
# 0      Monday    Espresso          25   4.99
# 1      Monday       Latte          15   4.99
# 2     Tuesday    Espresso          30   4.99
# 3     Tuesday       Latte          20   4.99
# 4   Wednesday    Espresso          35   4.99
# 5   Wednesday       Latte          25   4.99
# 6    Thursday    Espresso          40   4.99
# 7    Thursday       Latte          30   4.99
# 8      Friday    Espresso          45   4.99
# 9      Friday       Latte          35   4.99
# 10   Saturday    Espresso          45   4.99
# 11   Saturday       Latte          35   4.99
# 12     Sunday    Espresso          45   4.99
# 13     Sunday       Latte          35   4.99

# %%
import numpy as np
coffee_new["new_price"]=np.where(coffee_new["Coffee Type"]=="Latte",6.99,5.99)

# %%
coffee_new
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   4.99       5.99
# 1      Monday       Latte          15   4.99       6.99
# 2     Tuesday    Espresso          30   4.99       5.99
# 3     Tuesday       Latte          20   4.99       6.99
# 4   Wednesday    Espresso          35   4.99       5.99
# 5   Wednesday       Latte          25   4.99       6.99
# 6    Thursday    Espresso          40   4.99       5.99
# 7    Thursday       Latte          30   4.99       6.99
# 8      Friday    Espresso          45   4.99       5.99
# 9      Friday       Latte          35   4.99       6.99
# 10   Saturday    Espresso          45   4.99       5.99
# 11   Saturday       Latte          35   4.99       6.99
# 12     Sunday    Espresso          45   4.99       5.99
# 13     Sunday       Latte          35   4.99       6.99

# %%
coffee.drop(0)
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.drop(columns=["Day"])
# Out:
#    Coffee Type  Units Sold
# 0     Espresso          25
# 1        Latte          15
# 2     Espresso          30
# 3        Latte          20
# 4     Espresso          35
# 5        Latte          25
# 6     Espresso          40
# 7        Latte          30
# 8     Espresso          45
# 9        Latte          35
# 10    Espresso          45
# 11       Latte          35
# 12    Espresso          45
# 13       Latte          35

# %%
coffee_vnew=coffee_new

# %%
coffee_vnew.drop(columns=["Day"],inplace=True)

# %%
coffee_new
# Out:
#    Coffee Type  Units Sold  price  new_price
# 0     Espresso          25   4.99       5.99
# 1        Latte          15   4.99       6.99
# 2     Espresso          30   4.99       5.99
# 3        Latte          20   4.99       6.99
# 4     Espresso          35   4.99       5.99
# 5        Latte          25   4.99       6.99
# 6     Espresso          40   4.99       5.99
# 7        Latte          30   4.99       6.99
# 8     Espresso          45   4.99       5.99
# 9        Latte          35   4.99       6.99
# 10    Espresso          45   4.99       5.99
# 11       Latte          35   4.99       6.99
# 12    Espresso          45   4.99       5.99
# 13       Latte          35   4.99       6.99

# %%
coffee_vnew
# Out:
#    Coffee Type  Units Sold  price  new_price
# 0     Espresso          25   4.99       5.99
# 1        Latte          15   4.99       6.99
# 2     Espresso          30   4.99       5.99
# 3        Latte          20   4.99       6.99
# 4     Espresso          35   4.99       5.99
# 5        Latte          25   4.99       6.99
# 6     Espresso          40   4.99       5.99
# 7        Latte          30   4.99       6.99
# 8     Espresso          45   4.99       5.99
# 9        Latte          35   4.99       6.99
# 10    Espresso          45   4.99       5.99
# 11       Latte          35   4.99       6.99
# 12    Espresso          45   4.99       5.99
# 13       Latte          35   4.99       6.99

# %%
coffee_vvnew=coffee_new.copy()

# %%
coffee_vvnew=coffee_vvnew.drop(4)

# %%
coffee_vvnew
# Out:
#    Coffee Type  Units Sold  price  new_price
# 2     Espresso          30   4.99       5.99
# 3        Latte          20   4.99       6.99
# 5        Latte          25   4.99       6.99
# 6     Espresso          40   4.99       5.99
# 7        Latte          30   4.99       6.99
# 8     Espresso          45   4.99       5.99
# 9        Latte          35   4.99       6.99
# 10    Espresso          45   4.99       5.99
# 11       Latte          35   4.99       6.99
# 12    Espresso          45   4.99       5.99
# 13       Latte          35   4.99       6.99

# %%
coffee_new
# Out:
#    Coffee Type  Units Sold  price  new_price
# 0     Espresso          25   4.99       5.99
# 1        Latte          15   4.99       6.99
# 2     Espresso          30   4.99       5.99
# 3        Latte          20   4.99       6.99
# 4     Espresso          35   4.99       5.99
# 5        Latte          25   4.99       6.99
# 6     Espresso          40   4.99       5.99
# 7        Latte          30   4.99       6.99
# 8     Espresso          45   4.99       5.99
# 9        Latte          35   4.99       6.99
# 10    Espresso          45   4.99       5.99
# 11       Latte          35   4.99       6.99
# 12    Espresso          45   4.99       5.99
# 13       Latte          35   4.99       6.99

# %%
coffee_new
# Out:
#    Coffee Type  Units Sold  price  new_price
# 0     Espresso          25   4.99       5.99
# 1        Latte          15   4.99       6.99
# 2     Espresso          30   4.99       5.99
# 3        Latte          20   4.99       6.99
# 4     Espresso          35   4.99       5.99
# 5        Latte          25   4.99       6.99
# 6     Espresso          40   4.99       5.99
# 7        Latte          30   4.99       6.99
# 8     Espresso          45   4.99       5.99
# 9        Latte          35   4.99       6.99
# 10    Espresso          45   4.99       5.99
# 11       Latte          35   4.99       6.99
# 12    Espresso          45   4.99       5.99
# 13       Latte          35   4.99       6.99

# %%
coffee_new["revenue"]=coffee_new["Units Sold"]*coffee_new["new_price"]

# %%
coffee_new.head()
# Out:
#   Coffee Type  Units Sold  price  new_price  revenue
# 0    Espresso          25   4.99       5.99   149.75
# 1       Latte          15   4.99       6.99   104.85
# 2    Espresso          30   4.99       5.99   179.70
# 3       Latte          20   4.99       6.99   139.80
# 4    Espresso          35   4.99       5.99   209.65

# %%
coffee_new=coffee_new[["Coffee Type","revenue"]]

# %%
coffee_new
# Out:
#    Coffee Type  revenue
# 0     Espresso   149.75
# 1        Latte   104.85
# 2     Espresso   179.70
# 3        Latte   139.80
# 4     Espresso   209.65
# 5        Latte   174.75
# 6     Espresso   239.60
# 7        Latte   209.70
# 8     Espresso   269.55
# 9        Latte   244.65
# 10    Espresso   269.55
# 11       Latte   244.65
# 12    Espresso   269.55
# 13       Latte   244.65

# %%
coffee_new.rename(columns={"revenue":"Rev"},inplace=True)
# Out:
# C:\Users\SISAAkshayaB\AppData\Local\Temp\ipykernel_4680\183559411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee_new.rename(columns={"revenue":"Rev"},inplace=True)

# %%
coffee_new
# Out:
#    Coffee Type     Rev
# 0     Espresso  149.75
# 1        Latte  104.85
# 2     Espresso  179.70
# 3        Latte  139.80
# 4     Espresso  209.65
# 5        Latte  174.75
# 6     Espresso  239.60
# 7        Latte  209.70
# 8     Espresso  269.55
# 9        Latte  244.65
# 10    Espresso  269.55
# 11       Latte  244.65
# 12    Espresso  269.55
# 13       Latte  244.65

# %%
bios=pd.read_csv("./data/bios.csv")

# %%
bios_new=bios.copy()

# %%
a='Akshaya Balasubramani'.split()
print(a)
print(a[0])
# Out:
# ['Akshaya', 'Balasubramani']
# Akshaya

# %%
bios_new["First Name"]=bios_new["name"].str.split(" ").str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new["year"]=bios_new["born_date"].str.split("-").str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_data=bios_new[["name","born_date"]]

# %%
bios_data
# Out:
#                          name   born_date format_date
# 0       Jean-François Blanchy  1886-12-12  1886-12-12
# 1              Arnaud Boetsch  1969-04-01  1969-04-01
# 2                Jean Borotra  1898-08-13  1898-08-13
# 3             Jacques Brugnon  1895-05-11  1895-05-11
# 4                Albert Canet  1878-04-17  1878-04-17
# ...                       ...         ...         ...
# 145495      Polina Luchnikova  2002-01-30  2002-01-30
# 145496    Valeriya Merkusheva  1999-09-20  1999-09-20
# 145497        Yuliya Smirnova  1998-05-08  1998-05-08
# 145498         André Foussard  1899-05-19  1899-05-19
# 145499          Bill Phillips  1913-07-15  1913-07-15
#
# [145500 rows x 3 columns]

# %%
bios_data["format_date"]=pd.to_datetime(bios_data["born_date"],errors="coerce")
# Out:
# C:\Users\SISAAkshayaB\AppData\Local\Temp\ipykernel_4680\2062994228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios_data["format_date"]=pd.to_datetime(bios_data["born_date"],errors="coerce")

# %%
bios_data["year"]=bios_data["format_date"].dt.year
# Out:
# C:\Users\SISAAkshayaB\AppData\Local\Temp\ipykernel_4680\2935093635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios_data["year"]=bios_data["format_date"].dt.year

# %%
bios_data
# Out:
#                          name   born_date format_date    year
# 0       Jean-François Blanchy  1886-12-12  1886-12-12  1886.0
# 1              Arnaud Boetsch  1969-04-01  1969-04-01  1969.0
# 2                Jean Borotra  1898-08-13  1898-08-13  1898.0
# 3             Jacques Brugnon  1895-05-11  1895-05-11  1895.0
# 4                Albert Canet  1878-04-17  1878-04-17  1878.0
# ...                       ...         ...         ...     ...
# 145495      Polina Luchnikova  2002-01-30  2002-01-30  2002.0
# 145496    Valeriya Merkusheva  1999-09-20  1999-09-20  1999.0
# 145497        Yuliya Smirnova  1998-05-08  1998-05-08  1998.0
# 145498         André Foussard  1899-05-19  1899-05-19  1899.0
# 145499          Bill Phillips  1913-07-15  1913-07-15  1913.0
#
# [145500 rows x 4 columns]

# %%
bios_data["new_format"]=pd.to_datetime(bios_data["born_date"],format="%Y-%m-%d")
# Out:
# C:\Users\SISAAkshayaB\AppData\Local\Temp\ipykernel_4680\3148981159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios_data["new_format"]=pd.to_datetime(bios_data["born_date"],format="%Y-%m-%d")

# %%
bios_data
# Out:
#                          name   born_date format_date    year new_format
# 0       Jean-François Blanchy  1886-12-12  1886-12-12  1886.0 1886-12-12
# 1              Arnaud Boetsch  1969-04-01  1969-04-01  1969.0 1969-04-01
# 2                Jean Borotra  1898-08-13  1898-08-13  1898.0 1898-08-13
# 3             Jacques Brugnon  1895-05-11  1895-05-11  1895.0 1895-05-11
# 4                Albert Canet  1878-04-17  1878-04-17  1878.0 1878-04-17
# ...                       ...         ...         ...     ...        ...
# 145495      Polina Luchnikova  2002-01-30  2002-01-30  2002.0 2002-01-30
# 145496    Valeriya Merkusheva  1999-09-20  1999-09-20  1999.0 1999-09-20
# 145497        Yuliya Smirnova  1998-05-08  1998-05-08  1998.0 1998-05-08
# 145498         André Foussard  1899-05-19  1899-05-19  1899.0 1899-05-19
# 145499          Bill Phillips  1913-07-15  1913-07-15  1913.0 1913-07-15
#
# [145500 rows x 5 columns]

# %%
bios_data["month"]=bios_data["format_date"].dt.month
# Out:
# C:\Users\SISAAkshayaB\AppData\Local\Temp\ipykernel_4680\942408198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios_data["month"]=bios_data["format_date"].dt.month

# %%
bios_data
# Out:
#                          name   born_date format_date    year new_format  \
# 0       Jean-François Blanchy  1886-12-12  1886-12-12  1886.0 1886-12-12
# 1              Arnaud Boetsch  1969-04-01  1969-04-01  1969.0 1969-04-01
# 2                Jean Borotra  1898-08-13  1898-08-13  1898.0 1898-08-13
# 3             Jacques Brugnon  1895-05-11  1895-05-11  1895.0 1895-05-11
# 4                Albert Canet  1878-04-17  1878-04-17  1878.0 1878-04-17
# ...                       ...         ...         ...     ...        ...
# 145495      Polina Luchnikova  2002-01-30  2002-01-30  2002.0 2002-01-30
# 145496    Valeriya Merkusheva  1999-09-20  1999-09-20  1999.0 1999-09-20
# 145497        Yuliya Smirnova  1998-05-08  1998-05-08  1998.0 1998-05-08
# 145498         André Foussard  1899-05-19  1899-05-19  1899.0 1899-05-19
# 145499          Bill Phillips  1913-07-15  1913-07-15  1913.0 1913-07-15
#
#         month
# 0        12.0
# 1         4.0
# 2         8.0
# 3         5.0
# ...

# %%
bios_data.to_csv("./data/bios_data.csv",index=False)

# %%
bios_data.drop(0,inplace=True)
# Out:
# C:\Users\SISAAkshayaB\AppData\Local\Temp\ipykernel_4680\4293129002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios_data.drop(0,inplace=True)

# %%
bios_data.reindex()
# Out:
#                        name   born_date format_date    year new_format  month
# 1            Arnaud Boetsch  1969-04-01  1969-04-01  1969.0 1969-04-01    4.0
# 2              Jean Borotra  1898-08-13  1898-08-13  1898.0 1898-08-13    8.0
# 3           Jacques Brugnon  1895-05-11  1895-05-11  1895.0 1895-05-11    5.0
# 4              Albert Canet  1878-04-17  1878-04-17  1878.0 1878-04-17    4.0
# 5         Nicolas Chatelain  1970-01-13  1970-01-13  1970.0 1970-01-13    1.0
# ...                     ...         ...         ...     ...        ...    ...
# 145495    Polina Luchnikova  2002-01-30  2002-01-30  2002.0 2002-01-30    1.0
# 145496  Valeriya Merkusheva  1999-09-20  1999-09-20  1999.0 1999-09-20    9.0
# 145497      Yuliya Smirnova  1998-05-08  1998-05-08  1998.0 1998-05-08    5.0
# 145498       André Foussard  1899-05-19  1899-05-19  1899.0 1899-05-19    5.0
# 145499        Bill Phillips  1913-07-15  1913-07-15  1913.0 1913-07-15    7.0
#
# [145499 rows x 6 columns]

# %%
bios_data.reset_index()
# Out:
#          index                 name   born_date format_date    year  \
# 0            1       Arnaud Boetsch  1969-04-01  1969-04-01  1969.0
# 1            2         Jean Borotra  1898-08-13  1898-08-13  1898.0
# 2            3      Jacques Brugnon  1895-05-11  1895-05-11  1895.0
# 3            4         Albert Canet  1878-04-17  1878-04-17  1878.0
# 4            5    Nicolas Chatelain  1970-01-13  1970-01-13  1970.0
# ...        ...                  ...         ...         ...     ...
# 145494  145495    Polina Luchnikova  2002-01-30  2002-01-30  2002.0
# 145495  145496  Valeriya Merkusheva  1999-09-20  1999-09-20  1999.0
# 145496  145497      Yuliya Smirnova  1998-05-08  1998-05-08  1998.0
# 145497  145498       André Foussard  1899-05-19  1899-05-19  1899.0
# 145498  145499        Bill Phillips  1913-07-15  1913-07-15  1913.0
#
#        new_format  month
# 0      1969-04-01    4.0
# 1      1898-08-13    8.0
# 2      1895-05-11    5.0
# 3      1878-04-17    4.0
# ...

# %%
bios.set_index(bios["name"])
# Out:
#                        athlete_id                   name   born_date  \
# name
# Jean-François Blanchy           1  Jean-François Blanchy  1886-12-12
# Arnaud Boetsch                  2         Arnaud Boetsch  1969-04-01
# Jean Borotra                    3           Jean Borotra  1898-08-13
# Jacques Brugnon                 4        Jacques Brugnon  1895-05-11
# Albert Canet                    5           Albert Canet  1878-04-17
# ...                           ...                    ...         ...
# Polina Luchnikova          149222      Polina Luchnikova  2002-01-30
# Valeriya Merkusheva        149223    Valeriya Merkusheva  1999-09-20
# Yuliya Smirnova            149224        Yuliya Smirnova  1998-05-08
# André Foussard             149225         André Foussard  1899-05-19
# Bill Phillips              149814          Bill Phillips  1913-07-15
#
#                              born_city           born_region born_country  \
# name
# ...

# %%
bios_new.drop(columns=["athlete_id"],inplace=True)

# %%
bios_new.reindex()
# Out:
#                          name   born_date        born_city  \
# 0       Jean-François Blanchy  1886-12-12         Bordeaux
# 1              Arnaud Boetsch  1969-04-01           Meulan
# 2                Jean Borotra  1898-08-13         Biarritz
# 3             Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                Albert Canet  1878-04-17       Wandsworth
# ...                       ...         ...              ...
# 145495      Polina Luchnikova  2002-01-30            Serov
# 145496    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497        Yuliya Smirnova  1998-05-08           Kotlas
# 145498         André Foussard  1899-05-19            Niort
# 145499          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# ...

# %%
bios_new["height"]=bios["height_cm"].apply(lambda x:"Short" if x<165 else ("Average" if x<185 else 'Tall'))

# %%
bios_new
# Out:
#                          name   born_date        born_city  \
# 0       Jean-François Blanchy  1886-12-12         Bordeaux
# 1              Arnaud Boetsch  1969-04-01           Meulan
# 2                Jean Borotra  1898-08-13         Biarritz
# 3             Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                Albert Canet  1878-04-17       Wandsworth
# ...                       ...         ...              ...
# 145495      Polina Luchnikova  2002-01-30            Serov
# 145496    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497        Yuliya Smirnova  1998-05-08           Kotlas
# 145498         André Foussard  1899-05-19            Niort
# 145499          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# ...

# %%
def category(row):
    if row["height_cm"]<175 and row["weight_kg"]<70:
        return "Lightweight"
    elif row["height_cm"]<225 and row["weight_kg"]<100:
        return "Medium"
    else:
        return "Heavy"

# %%
bios_new["category"]=bios_new.apply(category,axis=1)

# %%
bios_new
# Out:
#                          name   born_date        born_city  \
# 0       Jean-François Blanchy  1886-12-12         Bordeaux
# 1              Arnaud Boetsch  1969-04-01           Meulan
# 2                Jean Borotra  1898-08-13         Biarritz
# 3             Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                Albert Canet  1878-04-17       Wandsworth
# ...                       ...         ...              ...
# 145495      Polina Luchnikova  2002-01-30            Serov
# 145496    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497        Yuliya Smirnova  1998-05-08           Kotlas
# 145498         André Foussard  1899-05-19            Niort
# 145499          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# ...
